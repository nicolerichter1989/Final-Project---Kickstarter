# %%
# 1. import libraries


import requests
from glob import glob
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
from time import sleep

HEADERS = ({'User-Agent' : 
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
            'Accept-Language' : '(KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'})

# %%
# import csv file

prod_tracker = pd.read_csv('Data/test.csv', sep=';')
prod_tracker_URLS = prod_tracker.url
prod_tracker
# Out:
#                                                   url  \
# 0   https://www.amazon.de/Apple-MWP22ZM-A-AirPods-...
# 1   https://www.amazon.de/Apple-iPhone-11-64-GB-Sc...
# 2   https://www.amazon.de/Neues-Apple-iPhone-Mini-...
# 3   https://www.amazon.de/Neues-Apple-iPad-Air-Wi-...
# 4   https://www.amazon.de/2021-Apple-iPad-Pro-Wi-F...
# 5   https://www.amazon.de/Neues-Apple-iPad-Air-Wi-...
# 6   https://www.amazon.de/Samsung-GQ65QN85AATXZG-Q...
# 7   https://www.amazon.de/Samsung-QLED-Q60T-Quantu...
# 8   https://www.amazon.de/Pampers-MONATSBOX-Hautsc...
# 9   https://www.amazon.de/AmazonBasics-Elektrische...
# 10  https://www.amazon.de/Amazonbasics-Roboter-Sta...
# 11  https://www.amazon.de/Stab-Staubsauger-leistun...
# 12  https://www.amazon.de/AmazonBasics-Advanced-Bl...
#
#                                               product  review  5 stars  \
# 0                         Apple-MWP22ZM-A-AirPods-Pro     NaN      NaN
# ...

# %%
page = requests.get(prod_tracker_URLS[0], headers = HEADERS)

# %%
soup = BeautifulSoup(page.content, features = 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="de-de"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
title = soup.find(id ='productTitle').get_text().strip()
title
# Out:
# 'Apple AirPods Pro'

# %%
price = float(soup.find(id='priceblock_ourprice').get_text().replace('.','').replace('€','').replace(',','.').strip())
price
# Out:
# 188.0

# %%
review_score = int(soup.select('#acrPopover .a-declarative')[0].i.get_text().split(' ')[0].replace(',','.'))
review_score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-763a914bc5b6> in <module>
# ----> 1 review_score = int(soup.select('#acrPopover .a-declarative')[0].i.get_text().split(' ')[0].replace(',','.'))
#       2 review_score
#
# ValueError: invalid literal for int() with base 10: '4.7'

# %%
review_count = int(soup.select('#acrCustomerReviewText')[0].get_text().split(' ')[0].replace('.',''))
review_count
# Out:
# 69165

# %%
soup.select('li:nth-child(7) .a-color-tertiary')[0].get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-ea6f196aeeba> in <module>
# ----> 1 soup.select('li:nth-child(7) .a-color-tertiary')[0].get_text().strip()
#
# IndexError: list index out of range

# %%
try:
    soup.select('#availability .a-color-state')[0].get_text().strip()
    stock = 'Out of Stock'
except:
    stock = 'Available'
    
stock
# Out:
# 'Available'

# %% [markdown]
# # try vueling
